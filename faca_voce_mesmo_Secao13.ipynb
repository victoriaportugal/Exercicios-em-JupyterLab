# %%
#para ler, organizar, analisar e transformar dados em tabelas no Python
import pandas as pd
#para criar gráficos e visualizações de dados no Python.
import matplotlib.pyplot as plt
#axes3d é para criar gráficos 3D com o Matplotlib
#Vem do módulo mpl_toolkits.mplot3d e permite visualizar dados em três dimensões
from mpl_toolkits.mplot3d import axes3d

# %%
dataset = pd.read_csv("dados.csv", sep=";")
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_424\24844956.py in <module>
# ----> 1 top5_pib = dados.sort_values(by='PIB', ascending=False).head(5)
#
# NameError: name 'dados' is not defined

# %%
agrupado = dataset.groupby(['MUNICIPIO'])['PIB'].sum()
agrupado
# Out:
# MUNICIPIO
# AGUDO                         16444.80
# AJURICABA                     20784.67
# ALECRIM                       11431.18
# ALMIRANTE TAMANDARE DO SUL    26895.37
# ALTO FELIZ                    13209.54
#                                 ...
# VERA CRUZ                     18417.96
# VIADUTOS                      12520.25
# VICTOR GRAEFF                 26700.28
# VILA MARIA                    31104.22
# VILA NOVA DO SUL              13053.13
# Name: PIB, Length: 177, dtype: float64

# %%
top5_pib = dataset.sort_values(by='PIB', ascending=False).head(5)
top5_pib
# Out:
#      CODIGO          MUNICIPIO        PIB  VALOREMPENHO
# 49      149            TRIUNFO  223848.22    1442759.82
# 146     453      MUITOS CAPOES   72353.72     140597.55
# 91      356          GARRUCHOS   68672.25     271841.26
# 176     108  SANTA CRUZ DO SUL   40671.53       9637.00
# 155     476      CAPAO DO CIPO   36739.78      60851.00

# %%
agrupado.plot.bar(color=['blue','yellow','red'])
# Out:
# <AxesSubplot: xlabel='MUNICIPIO'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_424\3584778337.py in <module>
# ----> 1 top5_pib.plot.pie()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in pie(self, **kwargs)
#    1581             and not kwargs.get("subplots", False)
#    1582         ):
# -> 1583             raise ValueError("pie requires either y column or 'subplots=True'")
#    1584         return self(kind="pie", **kwargs)
#    1585
#
# ValueError: pie requires either y column or 'subplots=True'
